# %% [markdown]
# # Exam — California Housing Investment Analysis
#
# ## Scenario
#
# You are working as a junior data analyst for a real-estate investment advisory firm.
#
# The firm wants to use the **California Housing dataset** to identify areas that may be interesting for different types of clients.
#
# Your task is to perform an end-to-end analysis and produce data-driven recommendations.
#
# You are expected to:
#
# - understand the dataset;
# - perform exploratory data analysis;
# - formulate and justify analytical choices;
# - define investment criteria for different clients;
# - build simple predictive models;
# - compare their performance;
# - use predictions carefully to support investment screening;
# - discuss the limitations of the analysis.
#
# ---
#
# ## Important instructions
#
# - You may use `pandas`, `numpy`, `matplotlib`, and `scikit-learn`.
# - You must justify your analytical choices in the markdown cells provided.
# - There is not always one single correct answer.
# - Good reasoning, interpretation, and awareness of limitations are part of the assessment.
# - Do not treat model output as direct investment advice.

# %% [markdown]
# # Part 1 — Data loading and understanding
#
# Load the California Housing dataset using `sklearn.datasets.fetch_california_housing`.
#
# Create a pandas DataFrame containing both the predictors and the target.
#
# Then answer the questions below.
#
# ### Questions
#
# 1. What is the unit of observation in this dataset?
# 2. Is each row an individual property?
# 3. What does the target variable represent?
# 4. In what unit is the target expressed?
# 5. Which variables may be especially useful for investment-related analysis?
# 6. Which important real-estate variables are missing?

# %%
# Write your code here

# %% [markdown]
# ### Your answers
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.

# %% [markdown]
# # Part 2 — Initial data inspection
#
# Perform an initial inspection of the dataset.
#
# Your analysis should include at least:
#
# - dataset shape;
# - column names;
# - data types;
# - missing values;
# - descriptive statistics;
# - identification of unusual or extreme values.
#
# ### Questions
#
# 1. Are there missing values?
# 2. Which variables appear skewed?
# 3. Which variables contain extreme values?
# 4. Do you notice anything unusual in the distribution of the target?
# 5. Could any variable have an artificial upper or lower cap?

# %%
# Write your code here

# %% [markdown]
# ### Interpretation
#
# Write a short interpretation of your findings.
#
# ...

# %% [markdown]
# # Part 3 — Exploratory Data Analysis
#
# Explore the relationship between housing characteristics and median house value.
#
# Your analysis must include:
#
# - at least three meaningful plots;
# - a correlation analysis;
# - at least one geographical visualization using latitude and longitude.
#
# You may choose the plots yourself.
#
# ### Questions
#
# 1. Which feature appears most strongly associated with house value?
# 2. Are all relationships approximately linear?
# 3. What information do latitude and longitude provide?
# 4. Why can geographical variables be useful even if their simple correlations with price are moderate?
# 5. Identify at least one relationship that deserves deeper investigation.

# %%
# Write your code here

# %% [markdown]
# ### Interpretation
#
# ...

# %% [markdown]
# # Part 4 — Investment clients
#
# The company has four different clients.
#
# You must translate each client's preferences into measurable criteria using the available variables.
#
# ## Client A — Budget-Oriented Investor
#
# This client wants to enter the market at a relatively low price but prefers economically stronger areas.
#
# Possible priorities include:
#
# - lower house value;
# - higher local income;
# - avoidance of very high occupancy.
#
# ## Client B — Premium Market Investor
#
# This client is less concerned about price and wants exposure to strong, expensive markets.
#
# Possible priorities include:
#
# - high median income;
# - high house values;
# - larger homes.
#
# ## Client C — Space-Oriented Investor
#
# This client prefers areas offering more living space and lower household crowding.
#
# Possible priorities include:
#
# - more rooms;
# - lower occupancy;
# - reasonable price.
#
# ## Client D — Value Investor
#
# This client wants to identify areas whose observed house value appears low relative to what a predictive model would expect from their characteristics.
#
# ---
#
# For Clients A, B, and C:
#
# 1. Define the variables you will use.
# 2. Explain whether each variable should be maximized or minimized.
# 3. Choose either:
#    - a filtering strategy,
#    - a ranking strategy,
#    - or a weighted score.
# 4. Justify your thresholds or weights.
# 5. Produce a ranked list of candidate areas.

# %% [markdown]
# ## Client A

# %%
# Define and implement your strategy for Client A

# %% [markdown]
# ### Justification
#
# ...

# %% [markdown]
# ## Client B

# %%
# Define and implement your strategy for Client B

# %% [markdown]
# ### Justification
#
# ...

# %% [markdown]
# ## Client C

# %%
# Define and implement your strategy for Client C

# %% [markdown]
# ### Justification
#
# ...

# %% [markdown]
# # Part 5 — Feature engineering
#
# Create at least **two derived variables** that may be useful for investment analysis.
#
# Examples include ratios or normalized indicators, but you may define your own.
#
# For each new feature:
#
# 1. provide the formula;
# 2. explain its meaning;
# 3. discuss one limitation.

# %%
# Create your new features here

# %% [markdown]
# ### Feature 1
#
# Formula:
# Meaning:
# Limitation:
#
# ### Feature 2
#
# Formula:
# Meaning:
# Limitation:

# %% [markdown]
# # Part 6 — Predictive modeling
#
# Your goal is now to predict median house value.
#
# Split the dataset into training and test sets.
#
# Build and evaluate the following models:
#
# 1. Baseline model;
# 2. Linear Regression;
# 3. Decision Tree Regressor;
# 4. One additional simple model of your choice.
#
# Examples:
#
# - Random Forest;
# - K-Nearest Neighbors;
# - Ridge Regression.
#
# Use at least:
#
# - MAE;
# - RMSE;
# - R² where appropriate.
#
# ### Questions
#
# 1. Why is a baseline model necessary?
# 2. Which model performs best?
# 3. Does the best predictive model necessarily provide the best explanation?
# 4. Which metric do you consider most useful in this business context, and why?

# %%
# Train/test split and baseline

# %%
# Linear Regression

# %%
# Decision Tree

# %%
# Additional model

# %%
# Compare model performance in a table

# %% [markdown]
# ### Model comparison
#
# ...

# %% [markdown]
# # Part 7 — Model interpretation
#
# Choose at least one of your predictive models and analyze how it uses the features.
#
# Depending on the model, you may use:
#
# - regression coefficients;
# - feature importances;
# - another appropriate simple interpretation method.
#
# ### Questions
#
# 1. Which variables are most influential in the model?
# 2. Are the results consistent with your EDA?
# 3. Can feature importance or regression coefficients be interpreted causally?
# 4. Identify one possible misleading interpretation.

# %%
# Write your interpretation code here

# %% [markdown]
# ### Interpretation
#
# ...

# %% [markdown]
# # Part 8 — Client D: model-based value screening
#
# Use your best predictive model to generate predicted house values.
#
# Create a variable similar to:
#
# `PredictionGap = PredictedValue - ObservedValue`
#
# Use this idea to search for areas that may deserve further investigation.
#
# ### Tasks
#
# 1. Generate predictions.
# 2. Compute a prediction gap.
# 3. Rank candidate areas.
# 4. Apply at least one additional business filter.
# 5. Select your top candidates.
#
# ### Questions
#
# 1. Why is a large positive prediction gap not proof that an area is undervalued?
# 2. What alternative explanations may produce the gap?
# 3. What additional data would you collect before investing?

# %%
# Implement Client D analysis here

# %% [markdown]
# ### Interpretation
#
# ...

# %% [markdown]
# # Part 9 — Error analysis
#
# Analyze where your best model performs poorly.
#
# You must identify at least:
#
# - the observations with the largest absolute errors;
# - whether errors seem geographically concentrated;
# - whether the model behaves differently for cheap and expensive areas.
#
# ### Questions
#
# 1. Does the model systematically underpredict or overpredict any group?
# 2. Are high-value areas harder to predict?
# 3. Could the structure of the target variable contribute to this?
# 4. What does this tell you about using the model in practice?

# %%
# Error analysis

# %% [markdown]
# ### Interpretation
#
# ...

# %% [markdown]
# # Part 10 — Final investment recommendation
#
# Prepare a concise recommendation for each client.
#
# For every client, report:
#
# - 3 to 5 candidate areas;
# - the criteria used;
# - why these areas were selected;
# - one important risk or limitation.
#
# You do not need to identify city names. Latitude and longitude may be used to represent candidate areas.
#
# ## Client A — Budget-Oriented Investor
#
# ...
#
# ## Client B — Premium Market Investor
#
# ...
#
# ## Client C — Space-Oriented Investor
#
# ...
#
# ## Client D — Value Investor
#
# ...

# %% [markdown]
# # Part 11 — Critical discussion
#
# Answer the following questions.
#
# ### Question 1
#
# Explain the difference between:
#
# - predicting current house value;
# - predicting future house-price appreciation;
# - predicting investment return.
#
# ### Question 2
#
# Why is this dataset insufficient for a real investment decision?
#
# Mention at least five missing variables.
#
# ### Question 3
#
# Suppose your Random Forest predicts house prices much better than Linear Regression.
#
# Give two reasons why you might still keep the Linear Regression model in the analysis.
#
# ### Question 4
#
# Explain why:
#
# > "The model predicts a high house value"
#
# does not imply:
#
# > "This is a good investment."
#
# ### Question 5
#
# Describe how you would extend this project if you had access to:
#
# - rental prices;
# - historical house prices;
# - mortgage rates;
# - property taxes;
# - crime statistics;
# - school quality;
# - distance from major cities.

# %% [markdown]
# # Optional bonus
#
# Choose **one** of the following.
#
# ## Bonus A — Cross-validation
#
# Evaluate at least two models using cross-validation.
#
# ## Bonus B — Classification
#
# Convert the problem into a classification task:
#
# - above-median house value;
# - below-median house value.
#
# Train and evaluate a simple classifier.
#
# ## Bonus C — Geographic feature engineering
#
# Create at least one new feature based on latitude and longitude.
#
# ## Bonus D — Sensitivity analysis
#
# Change the weights used for one client profile and measure how much the top-10 ranking changes.

# %%
# Optional bonus

# %% [markdown]
# # Suggested grading rubric
#
# | Section | Points |
# |---|---:|
# | Data understanding and inspection | 10 |
# | Exploratory data analysis | 15 |
# | Client A–C investment criteria | 15 |
# | Feature engineering | 10 |
# | Predictive modeling | 20 |
# | Model interpretation | 10 |
# | Client D value screening | 10 |
# | Final recommendations and critical discussion | 10 |
# | **Total** | **100** |
# | Optional bonus | **+5** |
#
# The quality of reasoning and interpretation is assessed together with the correctness of the code.
